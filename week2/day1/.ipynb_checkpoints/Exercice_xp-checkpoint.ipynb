# %% [markdown]
# # Exercice XP

# %% [markdown]
# 👩‍🏫 👩🏿‍🏫 What You Will Learn
# Fundamental concepts and the significance of data analysis in modern contexts
# Identification and classification of different data types, including qualitative vs. quantitative data
# Understanding structured and unstructured data, with techniques for converting unstructured data into structured formats
# Application of basic data analysis techniques using Python, Pandas, Matplotlib, and Seaborn
# Practical use of Jupyter Notebook and Google Colab for data analysis workflows
# Methods for importing datasets from multiple sources, including CSV files, JSON data from URLs, and Kaggle datasets
# Displaying, inspecting, and validating datasets using Pandas
# Applying data types effectively in analytical and business contexts
#
#
# 🛠️ What You Will Create
# Data Analysis Essay / Report (Exercise 1)
# A written report defining data analysis, explaining its importance, and discussing real-world applications.
#
# Data Type Classification Report (Exercise 2)
# An in-depth analysis of the Iris dataset, classifying each feature as qualitative or quantitative with clear justifications.
#
# Data Analysis Notebook (Exercise 3)
# A comprehensive Jupyter Notebook demonstrating:
#
# Statistical calculations (mean, median, mode)
#
# Data visualizations (histograms, bar charts)
# Clear documentation and interpretation of results
#
# Data Import & Structuring Scripts
#
# Import and explore the Titanic dataset directly from Kaggle
#
# Import the Iris dataset from a CSV file and display initial records
# Fetch and read JSON data from a URL using Pandas
# Convert raw and unstructured data into structured, analysis-ready formats

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exercie 1 : Introduction to Data Analysis (Easy)

# %% [markdown]
# Objective: Understand the basic overview and significance of data analysis.
# Task:
# Write a short essay or report on the following topics:
#
# What is data analysis?
# Why is data analysis important in modern contexts?
# List and describe three areas where data analysis is applied today.
# Hint/Tip:
#
# Research current trends in data analysis and real-world examples to provide depth to your essay.

# %% [markdown]
# ## What is Data Analysis?
#
# Data analysis is the systematic process of inspecting, cleaning, transforming, and modeling data to discover useful information, draw conclusions, and support decision-making. It involves applying statistical and computational techniques to extract meaningful patterns, trends, and insights from raw data. The process typically includes data collection, preprocessing, exploratory analysis, statistical modeling, and interpretation of results.
#
# Modern data analysis encompasses various methodologies, from descriptive statistics that summarize historical data to predictive analytics that forecast future trends, and prescriptive analytics that recommend optimal actions.
#
# ## Why is Data Analysis Important in Modern Contexts?
#
# Data analysis has become crucial in today's world for several compelling reasons:
#
# **1. Data Explosion**: We generate approximately 2.5 quintillion bytes of data daily. Without proper analysis, this vast information remains meaningless noise rather than actionable intelligence.
#
# **2. Competitive Advantage**: Organizations that effectively analyze data can identify market opportunities, optimize operations, and respond faster to changing conditions than their competitors.
#
# **3. Evidence-Based Decision Making**: Data analysis replaces intuition-based decisions with fact-driven strategies, reducing risks and improving outcomes across all sectors.
#
# **4. Efficiency and Cost Reduction**: By identifying inefficiencies and optimization opportunities, data analysis helps organizations streamline processes and reduce operational costs.
#
# **5. Personalization and Customer Experience**: Analysis of customer behavior enables personalized services, improving satisfaction and loyalty.
#
# ## Three Key Application Areas of Data Analysis
#
# ### 1. Healthcare and Medical Research
#
# Data analysis revolutionizes healthcare through:
# - **Electronic Health Records (EHR) Analysis**: Identifying treatment patterns and patient outcomes
# - **Drug Discovery**: Analyzing molecular data to accelerate pharmaceutical development
# - **Epidemiological Studies**: Tracking disease spread and effectiveness of public health interventions
# - **Personalized Medicine**: Using genetic and lifestyle data to tailor treatments
#
# *Real-world example*: During COVID-19, data analysis enabled real-time tracking of infection rates, vaccine effectiveness monitoring, and resource allocation optimization across healthcare systems globally.
#
# ### 2. Financial Services and Fintech
#
# The financial sector leverages data analysis for:
# - **Risk Assessment**: Evaluating creditworthiness and investment risks using historical and behavioral data
# - **Fraud Detection**: Identifying suspicious transactions through pattern recognition and anomaly detection
# - **Algorithmic Trading**: Using market data analysis for automated trading decisions
# - **Regulatory Compliance**: Monitoring transactions for anti-money laundering and compliance requirements
#
# *Real-world example*: Credit card companies analyze millions of transactions in real-time to detect fraudulent activities, preventing billions in losses annually while minimizing false positives that inconvenience customers.
#
# ### 3. E-commerce and Digital Marketing
#
# Online businesses utilize data analysis for:
# - **Customer Segmentation**: Grouping customers based on behavior, preferences, and demographics
# - **Recommendation Systems**: Suggesting products based on purchase history and browsing patterns
# - **Price Optimization**: Dynamic pricing based on demand, competition, and customer willingness to pay
# - **Supply Chain Management**: Optimizing inventory levels and logistics based on demand forecasting
#
# *Real-world example*: Amazon's recommendation engine, powered by collaborative filtering and machine learning algorithms, drives approximately 35% of their revenue by analyzing customer behavior patterns and purchase histories.
#
# ## Current Trends and Future Outlook
#
# Modern data analysis is evolving rapidly with trends including:
# - **Real-time Analytics**: Processing streaming data for immediate insights
# - **Artificial Intelligence Integration**: Combining traditional statistics with machine learning
# - **Automated Analytics**: Self-service platforms enabling non-technical users to perform analysis
# - **Edge Analytics**: Processing data closer to its source for faster decision-making
#
# ## Conclusion
#
# Data analysis has transformed from a specialized technical skill to a fundamental business capability. As data continues to grow exponentially, the ability to extract meaningful insights becomes increasingly valuable. Organizations across all sectors must invest in data analysis capabilities to remain competitive, make informed decisions, and deliver value to their stakeholders.
#
# ---
#
# ## Recommended Python Packages for Data Analysis:
#
# - **pandas**: Data manipulation and analysis
# - **numpy**: Numerical computing and array operations
# - **matplotlib/seaborn**: Data visualization
# - **scikit-learn**: Machine learning algorithms
# - **scipy**: Statistical analysis and scientific computing
# - **plotly**: Interactive visualizations
# - **jupyter**: Interactive development environment
# - **statsmodels**: Statistical modeling and econometrics

# %% [markdown]
# ## Exercice 2 : Dataset Loading and Initial Analysis

# %% [markdown]
# Objective: Practice dataset loading from Kaggle and initial analysis.
# Task:
# for the following dataset : How Much Sleep Do Americans Really Get?, Global Trends in Mental Health Disorder and Credit Card Approvals.
#
# Load the dataset into Jupyter or Google Colab.
# Display the first few rows.
# Provide a brief dataset description.

# %% [markdown]
# ### Load dataset

# %%
path = "./Data/Time Americans Spend Sleeping.csv"

# %%
df = pd.read_csv(path)

# %% [markdown]
# ### Display the first few rows

# %%
df.head()
# Out:
#    index  Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0      0  2003  Annual                      8.57           0.018     All days
# 1      1  2004  Annual                      8.55           0.026     All days
# 2      2  2005  Annual                      8.62           0.023     All days
# 3      3  2006  Annual                      8.63           0.024     All days
# 4      4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %% [markdown]
# ### Description

# %%
df.describe()
# Out:
#             index         Year  Avg hrs per day sleeping  Standard Error
# count  945.000000   945.000000                945.000000      945.000000
# mean   472.000000  2010.000000                  8.806868        0.086958
# std    272.942302     4.322782                  0.545001        0.034631
# min      0.000000  2003.000000                  7.720000        0.018000
# 25%    236.000000  2006.000000                  8.360000        0.063000
# 50%    472.000000  2010.000000                  8.810000        0.084000
# 75%    708.000000  2014.000000                  9.190000        0.106000
# max    944.000000  2017.000000                 10.650000        0.228000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   index                     945 non-null    int64
#  1   Year                      945 non-null    int64
#  2   Period                    945 non-null    object
#  3   Avg hrs per day sleeping  945 non-null    float64
#  4   Standard Error            945 non-null    float64
#  5   Type of Days              945 non-null    object
#  6   Age Group                 945 non-null    object
#  7   Activity                  945 non-null    object
#  8   Sex                       945 non-null    object
# dtypes: float64(2), int64(2), object(5)
# memory usage: 66.6+ KB

# %% [markdown]
# ## Exercise 3: Identifying Data Types

# %% [markdown]
# Objective: Learn to identify different data types.
# Task:
# For the datasets from the previous exercise, categorize each column of it as either quantitative or qualitative and explain your reasoning.

# %%
df = df.drop(columns=["index"])

# %%
df.head()
# Out:
#    Year  Period  Avg hrs per day sleeping  Standard Error Type of Days  \
# 0  2003  Annual                      8.57           0.018     All days
# 1  2004  Annual                      8.55           0.026     All days
# 2  2005  Annual                      8.62           0.023     All days
# 3  2006  Annual                      8.63           0.024     All days
# 4  2007  Annual                      8.57           0.024     All days
#
#            Age Group  Activity   Sex
# 0  15 years and over  Sleeping  Both
# 1  15 years and over  Sleeping  Both
# 2  15 years and over  Sleeping  Both
# 3  15 years and over  Sleeping  Both
# 4  15 years and over  Sleeping  Both

# %%
columns_analysis = {
    
    'Year': {
        'type': 'Quantitative - Discrete (Temporal)',
        'reasoning': 'Numeric values representing specific years; discrete time points with meaningful order'
    },
    'Period': {
        'type': 'Qualitative - Categorical',
        'reasoning': 'Text describing time period type; represents categories of measurement periods'
    },
    'Avg hrs per day sleeping': {
        'type': 'Quantitative - Continuous',
        'reasoning': 'Decimal numbers representing measurable quantities; can take any value within a reasonable range'
    },
    'Standard Error': {
        'type': 'Quantitative - Continuous',
        'reasoning': 'Decimal numbers representing statistical measure of precision; continuous measurement values'
    },
    'Type of Days': {
        'type': 'Qualitative - Categorical',
        'reasoning': 'Text describing categories of days being measured; represents distinct groups'
    },
    'Age Group': {
        'type': 'Qualitative - Ordinal',
        'reasoning': 'Text representing age categories; has implicit ordering (younger to older ages)'
    },
    'Activity': {
        'type': 'Qualitative - Categorical',
        'reasoning': 'Text describing the type of activity being measured; represents distinct categories'
    },
    'Sex': {
        'type': 'Qualitative - Categorical',
        'reasoning': 'Text representing gender categories; distinct groups for demographic classification'
    }
}

# %%
df_types = pd.DataFrame(df)

# Analyze each column
print("DATA TYPE CATEGORIZATION")

print("-" * 70)

# Display detailed analysis
for column, analysis in columns_analysis.items():
    print(f"\nColumn: '{column}'")
    print(f"Type: {analysis['type']}")
    print(f"Reasoning: {analysis['reasoning']}")
    print(f"Sample values: {df[column].unique()[:3]}")
    print(f"Data type in pandas: {df[column].dtype}")
# Out:
# DATA TYPE CATEGORIZATION
# ----------------------------------------------------------------------
#
# Column: 'Year'
# Type: Quantitative - Discrete (Temporal)
# Reasoning: Numeric values representing specific years; discrete time points with meaningful order
# Sample values: [2003 2004 2005]
# Data type in pandas: int64
#
# Column: 'Period'
# Type: Qualitative - Categorical
# Reasoning: Text describing time period type; represents categories of measurement periods
# Sample values: ['Annual']
# Data type in pandas: object
#
# Column: 'Avg hrs per day sleeping'
# Type: Quantitative - Continuous
# Reasoning: Decimal numbers representing measurable quantities; can take any value within a reasonable range
# Sample values: [8.57 8.55 8.62]
# Data type in pandas: float64
#
# Column: 'Standard Error'
# Type: Quantitative - Continuous
# Reasoning: Decimal numbers representing statistical measure of precision; continuous measurement values
# Sample values: [0.018 0.026 0.023]
# ...

# %% [markdown]
# ## Exercise 4: Exploring Data Types

# %% [markdown]
# Objective: Learn about different types of data in data analysis.
# Task:
# Load the Iris dataset using Kaggle into a Jupyter Notebook or Google Colaboratory Notebook.
# Identify and list which columns in your dataset are qualitative and which are quantitative.
# Write a brief description of why each column is classified as qualitative or quantitative.
# Tools: Jupyter Notebook, Python with Pandas library.

# %%
path_ex4 = "./Data/Iris.csv"

# %%
df_ex4 = pd.read_csv(path_ex4)
df_ex4.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df_ex4 = df_ex4.drop(columns = ["Id"])

# %%
df_ex4.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Identify quantitative and qualitative columns programmatically
quantitative_columns = df.select_dtypes(include=[np.number]).columns.tolist()
qualitative_columns = df.select_dtypes(include=['object', 'category']).columns.tolist()

print("Column Classification:")
print("=" * 50)
print(f"Quantitative Columns: {quantitative_columns}")
print(f"Qualitative Columns: {qualitative_columns}")
print("\n")

# Detailed analysis of each column
print("Detailed Column Analysis:")
print("=" * 50)
for column in df.columns:
    if column in quantitative_columns:
        print(f"{column}: Quantitative (Continuous)")
        print(f"  - Range: {df[column].min():.2f} to {df[column].max():.2f}")
        print(f"  - Mean: {df[column].mean():.2f}")
    else:
        print(f"{column}: Qualitative (Categorical)")
        print(f"  - Unique values: {df[column].unique()}")
        print(f"  - Number of categories: {df[column].nunique()}")
    print()

# %%
df_types = pd.DataFrame(df_ex4)

# Analyze each column
print("DATA TYPE CATEGORIZATION")

print("-" * 70)

# Display detailed analysis
for column, analysis in columns_analysis.items():
    print(f"\nColumn: '{column}'")
    print(f"Type: {analysis['type']}")
    print(f"Reasoning: {analysis['reasoning']}")
    print(f"Sample values: {df[column].unique()[:3]}")
    print(f"Data type in pandas: {df[column].dtype}")

# %% [markdown]
# ## Exercice 5
